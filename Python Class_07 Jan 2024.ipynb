# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

pos = 0
while pos < len(my_str):
    print(my_str[pos])
    if my_str[pos].lower() == 't':
        while my_str[pos] != "":
            print(my_str[pos])
            pos = pos + 1
            
    else :
        pos = pos + 1
# Out:
# A
# l
# t
# t
# h
# o
# u
# g
# h
#
# 8
#
# t
# h
# a
# t
#
# w
# a
# y
#
# m
# a
# y
#
# n
# o
# t
#
# b
# e
#
# o
# b
# v
# i
# o
# u
# s
#
# a
# t
#
# f
# i
# r
# s
# t
#
# u
# n
# l
# e
# s
# s
#
# y
# o
# u
# '
# r
# e
#
# d
# u
# t
# c
# h
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 7
#       5 print(my_str[pos])
#       6 if my_str[pos].lower() == 't':
# ----> 7     while my_str[pos] != "":
#       8         print(my_str[pos])
#       9         pos = pos + 1
#
# IndexError: string index out of range

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

TempList = my_str.split(" ")
print(TempList)
for element in TempList :
    if element.lower().count('t') > 0:
        position = 
        print(element)
# Out:
# ['Although', '8', 'that', 'way', 'may', 'not', 'be', 'obvious', 'at', 'first', 'unless', "you're", 'dutch']
# Although
# that
# not
# at
# first
# dutch

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    pattern = ""
    if my_str[pos].lower() == "t":
        while my_str[pos] != " ":
            pattern = pattern + my_str[pos]
            pos = pos+1
        ans.append(pattern)
    else :
        pos = pos + 1
        
print(ans)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 8
#       6 pattern = ""
#       7 if my_str[pos].lower() == "t":
# ----> 8     while my_str[pos] != " ":
#       9         pattern = pattern + my_str[pos]
#      10         pos = pos+1
#
# IndexError: string index out of range

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    pattern = ""
    if my_str[pos].lower() == "t":
        while my_str[pos] != " ":
            pattern = pattern + my_str[pos]
            pos = pos+1
            ans.append(pattern)
    else :
        pos = pos + 1
        
print(ans)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 8
#       6 pattern = ""
#       7 if my_str[pos].lower() == "t":
# ----> 8     while my_str[pos] != " ":
#       9         pattern = pattern + my_str[pos]
#      10         pos = pos+1
#
# IndexError: string index out of range

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    print("Parent Loop :", my_str[pos])
    pos = pos + 1
# Out:
# Parent Loop : A
# Parent Loop : l
# Parent Loop : t
# Parent Loop : h
# Parent Loop : o
# Parent Loop : u
# Parent Loop : g
# Parent Loop : h
# Parent Loop :
# Parent Loop : 8
# Parent Loop :
# Parent Loop : t
# Parent Loop : h
# Parent Loop : a
# Parent Loop : t
# Parent Loop :
# Parent Loop : w
# Parent Loop : a
# Parent Loop : y
# Parent Loop :
# Parent Loop : m
# Parent Loop : a
# Parent Loop : y
# Parent Loop :
# Parent Loop : n
# Parent Loop : o
# Parent Loop : t
# Parent Loop :
# Parent Loop : b
# Parent Loop : e
# Parent Loop :
# Parent Loop : o
# Parent Loop : b
# Parent Loop : v
# Parent Loop : i
# Parent Loop : o
# Parent Loop : u
# Parent Loop : s
# Parent Loop :
# Parent Loop : a
# Parent Loop : t
# Parent Loop :
# Parent Loop : f
# Parent Loop : i
# Parent Loop : r
# Parent Loop : s
# Parent Loop : t
# Parent Loop :
# Parent Loop : u
# Parent Loop : n
# Parent Loop : l
# Parent Loop : e
# Parent Loop : s
# Parent Loop : s
# Parent Loop :
# Parent Loop : y
# ...

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    print("Parent Loop :", my_str[pos])
    pos = pos + 1
    if my_str[pos].lower() == "t":
        while my_str[pos] != " ":
            print("Child Loop : ", my_str[pos])
            pattern = pattern + my_str[pos]
            pos = pos + 1
    else :
        pos = pos + 1
# Out:
# Parent Loop : A
# Parent Loop : t
# Parent Loop : o
# Parent Loop : g
# Parent Loop :
# Parent Loop :
# Child Loop :  t
# Child Loop :  h
# Child Loop :  a
# Child Loop :  t
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : o
# Child Loop :  t
# Parent Loop :
# Parent Loop : e
# Parent Loop : o
# Parent Loop : v
# Parent Loop : o
# Parent Loop : s
# Parent Loop : a
# Child Loop :  t
# Parent Loop :
# Parent Loop : i
# Parent Loop : s
# Child Loop :  t
# Parent Loop :
# Parent Loop : n
# Parent Loop : e
# Parent Loop : s
# Parent Loop : y
# Parent Loop : u
# Parent Loop : r
# Parent Loop :
# Parent Loop : u
# Child Loop :  t
# Child Loop :  c
# Child Loop :  h
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 9
#       7 pos = pos + 1
#       8 if my_str[pos].lower() == "t":
# ...

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    print("Parent Loop :", my_str[pos])
    pos = pos + 1
# Out:
# Parent Loop : A
# Parent Loop : l
# Parent Loop : t
# Parent Loop : h
# Parent Loop : o
# Parent Loop : u
# Parent Loop : g
# Parent Loop : h
# Parent Loop :
# Parent Loop : 8
# Parent Loop :
# Parent Loop : t
# Parent Loop : h
# Parent Loop : a
# Parent Loop : t
# Parent Loop :
# Parent Loop : w
# Parent Loop : a
# Parent Loop : y
# Parent Loop :
# Parent Loop : m
# Parent Loop : a
# Parent Loop : y
# Parent Loop :
# Parent Loop : n
# Parent Loop : o
# Parent Loop : t
# Parent Loop :
# Parent Loop : b
# Parent Loop : e
# Parent Loop :
# Parent Loop : o
# Parent Loop : b
# Parent Loop : v
# Parent Loop : i
# Parent Loop : o
# Parent Loop : u
# Parent Loop : s
# Parent Loop :
# Parent Loop : a
# Parent Loop : t
# Parent Loop :
# Parent Loop : f
# Parent Loop : i
# Parent Loop : r
# Parent Loop : s
# Parent Loop : t
# Parent Loop :
# Parent Loop : u
# Parent Loop : n
# Parent Loop : l
# Parent Loop : e
# Parent Loop : s
# Parent Loop : s
# Parent Loop :
# Parent Loop : y
# ...

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    print("Parent Loop :", my_str[pos])
    pos = pos + 1
    if my_str[pos].lower() == "t":
        while my_str[pos] != " " :
            print("Child Loop : ", my_str[pos])
            pattern = pattern + my_str[pos]
            pos = pos + 1
            
    else :
        pos = pos + 1
# Out:
# Parent Loop : A
# Parent Loop : t
# Parent Loop : o
# Parent Loop : g
# Parent Loop :
# Parent Loop :
# Child Loop :  t
# Child Loop :  h
# Child Loop :  a
# Child Loop :  t
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : o
# Child Loop :  t
# Parent Loop :
# Parent Loop : e
# Parent Loop : o
# Parent Loop : v
# Parent Loop : o
# Parent Loop : s
# Parent Loop : a
# Child Loop :  t
# Parent Loop :
# Parent Loop : i
# Parent Loop : s
# Child Loop :  t
# Parent Loop :
# Parent Loop : n
# Parent Loop : e
# Parent Loop : s
# Parent Loop : y
# Parent Loop : u
# Parent Loop : r
# Parent Loop :
# Parent Loop : u
# Child Loop :  t
# Child Loop :  c
# Child Loop :  h
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 9
#       7 pos = pos + 1
#       8 if my_str[pos].lower() == "t":
# ...

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"
mylist = my_str.split(" ")

for word in mylist:
    if "t" in word.lower():
        print(word)
# Out:
# Although
# that
# not
# at
# first
# dutch

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"
mylist = my_str.split(" ")
newlist = []
for word in mylist:
    if "t" in word.lower():
        tposition = word.lower().index("t")
        newlist.append(word[tposition : :])
            
print(newlist)
# Out:
# ['though', 'that', 't', 't', 't', 'tch']

# %%
my_str = "Although 8 that way may not be obvious at first unless you're dutch"

ans = []
pos = 0
while pos < len(my_str):
    print("Parent Loop :", my_str[pos])
    pos = pos + 1
    if pos < len(my_str) and my_str[pos].lower() == "t":
        while pos < len(my_str) and my_str[pos] != " ":
            print("Child Loop : ", my_str[pos])
            # You need to initialize 'pattern' before using it
            pattern = my_str[pos]
            pos = pos + 1
            while pos < len(my_str) and my_str[pos] != " ":
                pattern = pattern + my_str[pos]
                pos = pos + 1
    else:
        pos = pos + 1
# Out:
# Parent Loop : A
# Parent Loop : t
# Parent Loop : o
# Parent Loop : g
# Parent Loop :
# Parent Loop :
# Child Loop :  t
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : a
# Parent Loop :
# Parent Loop : o
# Child Loop :  t
# Parent Loop :
# Parent Loop : e
# Parent Loop : o
# Parent Loop : v
# Parent Loop : o
# Parent Loop : s
# Parent Loop : a
# Child Loop :  t
# Parent Loop :
# Parent Loop : i
# Parent Loop : s
# Child Loop :  t
# Parent Loop :
# Parent Loop : n
# Parent Loop : e
# Parent Loop : s
# Parent Loop : y
# Parent Loop : u
# Parent Loop : r
# Parent Loop :
# Parent Loop : u
# Child Loop :  t

# %%
Type of Functions

# Positional Arguments : Very important to know while passing values
# Keyword Arguments : 
# Default Arguments : 
# Variable length arguments :
